# %%
print("=== Welcome to ATM Simulator 1913 ===")
user_account = ("Shehroz Alam", "1234")  # tuple
transaction_history = []  # list

balance = 5000

pin_account = input("Enter 4 number pin: ")
if pin_account != user_account[1]:
    print("Incorrect PIN. Access denied.")
else:
    while True:
        print("\nPlease select an option:")
        print("1. Check Balance")
        print("2. Deposit Money")
        print("3. Withdraw Money")
        print("4. Transaction History")
        print("5. Exit")

        choice = input("Enter your choice (1-5): ")

        if choice == "1":
            print(f"Your current balance is: Rs {balance}")
            transaction_history.append(f"Checked Balance: {balance}")
            print("______________________________________")

        elif choice == "2":
            try:
                amount = int(input("Enter amount to deposit: "))
                if amount > 0:
                    balance += amount
                    print(f"Rs {amount} deposited successfully.")
                    print(f"New balance: Rs {balance}")
                    transaction_history.append(f"Deposited Rs: {amount}")
                else:
                    print("Please enter a positive amount.")
            except ValueError:
                print("Invalid input. Please enter a numeric value.")
            print("_______________________________________")

        elif choice == "3":
            try:
                amount = int(input("Enter amount to withdraw: "))
                if amount > 0:
                    if amount <= balance:
                        balance -= amount
                        print(f"Rs {amount} withdrawn successfully.")
                        print(f"New balance: Rs {balance}")
                        transaction_history.append(f"Withdrew Rs {amount}")
                    else:
                        print("Insufficient balance!")
                else:
                    print("Please enter a positive amount.")
            except ValueError:
                print("Invalid input. Please enter a numeric value.")
            print("_______________________________________")

        elif choice == "4":
            print("\n--- Transaction History ---")
            if transaction_history:
                for t in transaction_history:
                    print("-", t)
            else:
                print("No transactions yet.")
            print("_______________________________________")

        elif choice == "5":
            print("Thank you for using the ATM. Goodbye!")
            break

        else:
            print("Invalid choice. Please try again.")
# Out:
# === Welcome to ATM Simulator 1913 ===
# Enter 4 number pin: 1234
#
# Please select an option:
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Transaction History
# 5. Exit
# Enter your choice (1-5): 5
# Thank you for using the ATM. Goodbye!
